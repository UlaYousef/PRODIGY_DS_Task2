# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("SFsalaries.csv")
df
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# all values of Notes column are null so we will drop it
#
# more than 70% of Status column are null so we will drop it too
#
# we will drop also Agency column because it has the same value for all data (nothing significant with it)

# %%
column=['Notes','Status','Agency']
df.drop(columns=column,axis=1,inplace=True)

# %% [markdown]
# now let's take a look on BasePay and Benefits column

# %%
print(" Benefits unique values are:",df['Benefits'].unique)
print("\n")
print(" BasePay unique values are:",df['BasePay'].unique)
# Out:
#  Benefits unique values are: <bound method Series.unique of 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: Benefits, Length: 148654, dtype: object>
#
#
#  BasePay unique values are: <bound method Series.unique of 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object>

# %%
df.loc[df['Benefits']=='Not Provided']
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year
# 148646  Not Provided  Not Provided       0.0               0.0  2014
# 148650  Not Provided  Not Provided       0.0               0.0  2014
# 148651  Not Provided  Not Provided       0.0               0.0  2014
# 148652  Not Provided  Not Provided       0.0               0.0  2014

# %%
df.loc[df['BasePay']=='Not Provided']
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year
# 148646  Not Provided  Not Provided       0.0               0.0  2014
# 148650  Not Provided  Not Provided       0.0               0.0  2014
# 148651  Not Provided  Not Provided       0.0               0.0  2014
# 148652  Not Provided  Not Provided       0.0               0.0  2014

# %% [markdown]
# comapring the previous result we find that when both value of BasePay and Beneifts column are Not Provided the all values of column in the same smaple will NaN or Not Provided so we will drop the samples that correspond with this condition by droping their index

# %%
df.drop(index=[148646,148650,148651,148652],inplace=True)

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# dtype: object

# %% [markdown]
# we have many numeric column their dtypes has been defined as object,so we need to convert it to numeric ones

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'])
df['OvertimePay'] = pd.to_numeric(df['OvertimePay'])
df['OtherPay'] = pd.to_numeric(df['OtherPay'])
df['Benefits'] = pd.to_numeric(df['Benefits'])

# %%
df.loc[df['Benefits'].isnull()==True].head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
df.loc[df['Benefits'].isnull()==True].tail(10)
# Out:
#           Id        EmployeeName                                    JobTitle  \
# 36149  36150             ANH LUU                                       CLERK
# 36150  36151     WALTER WILLIAMS                                LIBRARY PAGE
# 36151  36152         MARVA MOORE                            TRANSIT OPERATOR
# 36152  36153     MARCELLA TUCKER                            TRANSIT OPERATOR
# 36153  36154       ROCK CRAWFORD                                 FIREFIGHTER
# 36154  36155       SERENA HUGHES          SWIMMING INSTRUCTOR/POOL LIFEGUARD
# 36155  36156        JOE BROWN JR                            TRANSIT OPERATOR
# 36156  36157      PAULETTE ADAMS  STATIONARY ENGINEER, WATER TREATMENT PLANT
# 36157  36158       KAUKAB MOHSIN                            TRANSIT OPERATOR
# 36158  36159  JOSEPHINE MCCREARY                                  MANAGER IV
#
#        BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
df.loc[df['Benefits'].isnull()==True]
# Out:
#           Id        EmployeeName  \
# 0          1      NATHANIEL FORD
# 1          2        GARY JIMENEZ
# 2          3      ALBERT PARDINI
# 3          4   CHRISTOPHER CHONG
# 4          5     PATRICK GARDNER
# ...      ...                 ...
# 36154  36155       SERENA HUGHES
# 36155  36156        JOE BROWN JR
# 36156  36157      PAULETTE ADAMS
# 36157  36158       KAUKAB MOHSIN
# 36158  36159  JOSEPHINE MCCREARY
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %% [markdown]
# looking at previous dataframe we notice the following: TotalBay is the sum of BasePay,OvertimePay,OtherPay
#
# TotalPayBenefits is the sum of TotalBay and Benefits
#
# when Benefits has NaN value the TotalPay is equal to TotalPayBenefits so Benefits is equal to zero

# %%
df.loc[df['Benefits'].isnull()==False]
# Out:
#             Id        EmployeeName                      JobTitle    BasePay  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr               Chief of Police  302578.00
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech  111921.00
# 36162    36163  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                           ...        ...
# 148645  148646    Carolyn A Wilson     Human Services Technician       0.00
# 148647  148648      Joann Anderson   Communications Dispatcher 2       0.00
# 148648  148649         Leon Walker                     Custodian       0.00
# 148649  148650       Roy I Tillery                     Custodian       0.00
# 148653  148654           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
# ...

# %%
df.loc[df['TotalPayBenefits'].values ==df['TotalPay'].values]
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148645                       Human Services Technician       0.00
# ...

# %%
def impute_Benefits(cols):
    Benefits = cols[0]
    TotalPayBenefits = cols[1]
    TotalPay = cols[2]
    if pd.isnull(Benefits):

        if TotalPayBenefits == TotalPay :
            return 0.0
    else:
        return Benefits

# %%
df['Benefits'] = df[['Benefits','TotalPayBenefits','TotalPay']].apply(impute_Benefits,axis=1)

# %%
df.loc[df['Benefits'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
df.loc[df['BasePay'].isnull()==True]
# Out:
#             Id       EmployeeName                   JobTitle  BasePay  \
# 81391    81392    Kevin P Cashman             Deputy Chief 3      NaN
# 84506    84507  Demetrya  Mullens  Licensed Vocational Nurse      NaN
# 84960    84961    Michael M Horan        Park Patrol Officer      NaN
# 90525    90526       Thomas  Tang           Police Officer 3      NaN
# 90786    90787     Michael C Hill             Deputy Sheriff      NaN
# ...        ...                ...                        ...      ...
# 110526  110527     Arthur L Curry    PS Aide Health Services      NaN
# 110527  110528      Nereida  Vega               Senior Clerk      NaN
# 110528  110529   Timothy E Gibson           Police Officer 3      NaN
# 110529  110530     Mark E Laherty           Police Officer 3      NaN
# 110530  110531      David P Kucia           Police Officer 3      NaN
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# ...

# %% [markdown]
# looking at previous dataframe we notice the following: TotalBay is the sum of BasePay,OvertimePay,OtherPay
#
# TotalPayBenefits is the sum of TotalBay and Benefits
#
# when BasePay has NaN value the TotalPay is equal to OtherPay, the OvertimePay is equal to zero
#
# so BasePay is equal to zero

# %%
def impute_BasePay(cols):
    BasePay = cols[0]
    TotalPay = cols[1]
    OtherPay = cols[2]
    OvertimePay= cols[3]
    if pd.isnull(BasePay):
        if OtherPay == TotalPay and OvertimePay==0.0:
            return 0.0
    else:
        return BasePay

# %%
df['BasePay'] = df[['BasePay','TotalPay','OtherPay','OvertimePay']].apply(impute_BasePay,axis=1)

# %%
df.loc[df['BasePay'].isnull()==True]
# Out:
#             Id         EmployeeName            JobTitle  BasePay  OvertimePay  \
# 106695  106696      Leonard  Taylor    Transit Operator      NaN        29.52
# 108066  108067     Kris A Bleything  Nurse Practitioner      NaN       706.40
# 109246  109247  Cristina  Santillan       Special Nurse      NaN      1730.93
# 109845  109846    Sarah M Eichstedt       Special Nurse      NaN       793.60
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# 106695      0.00   7959.18     29.52           7988.70  2013
# 108066   3364.75    564.47   4071.15           4635.62  2013
# 109246      0.00    340.49   1730.93           2071.42  2013
# 109845      0.00    146.43    793.60            940.03  2013

# %% [markdown]
# there are missing values still in BasePay column, but we notice from above that TotalPay is just the sum of OvertimePay and OtherPay so BasePay is also equal to zero

# %%
def impute_BasePay2(cols):
    BasePay = cols[0]
    TotalPay = cols[1]
    OtherPay = cols[2]
    OvertimePay= cols[3]
    if pd.isnull(BasePay):
        if TotalPay == OtherPay + OvertimePay:
            return 0.0
    else:
        return BasePay

# %%
df['BasePay'] = df[['BasePay','TotalPay','OtherPay','OvertimePay']].apply(impute_BasePay2,axis=1)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148645                       Human Services Technician       0.00
# ...

# %% [markdown]
# we notice from the data above:
#
# the value of JobTitle and EmployeeName column sometimes has been written in uppercase and sometimes in lowercase so we will unify them all to lowercase

# %%
df['JobTitle']=df['JobTitle'].map(str.lower)
df['EmployeeName']=df['EmployeeName'].map(str.lower)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     nathaniel ford
# 1            2       gary jimenez
# 2            3     albert pardini
# 3            4  christopher chong
# 4            5    patrick gardner
# ...        ...                ...
# 148645  148646   carolyn a wilson
# 148647  148648     joann anderson
# 148648  148649        leon walker
# 148649  148650      roy i tillery
# 148653  148654          joe lopez
#
#                                               JobTitle    BasePay  \
# 0       general manager-metropolitan transit authority  167411.18
# 1                      captain iii (police department)  155966.02
# 2                      captain iii (police department)  212739.13
# 3                 wire rope cable maintenance mechanic   77916.00
# 4         deputy chief of department,(fire department)  134401.60
# ...                                                ...        ...
# 148645                       human services technician       0.00
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Length: 148650, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
f=df.filter(items=['JobTitle','BasePay','OvertimePay','OtherPay','Benefits','TotalPay','TotalPayBenefits','Year'])
f2=pd.DataFrame(f)

# %%
f2.duplicated().sum()
# Out:
# 4760

# %%
f2.drop_duplicates(inplace=True)

# %%
f2.duplicated().sum()
# Out:
# 0

# %%
f2.nlargest(n=10,columns="TotalPay")
# Out:
#                                               JobTitle    BasePay  \
# 0       general manager-metropolitan transit authority  167411.18
# 1                      captain iii (police department)  155966.02
# 110531                                  deputy chief 3  129150.01
# 110532                               asst med examiner  318835.49
# 36159                     lieutenant, fire suppression  128808.87
# 36167                                        captain 3  104404.00
# 72927                   battalion chief, fire suppress  186236.42
# 110536                               asst med examiner  270222.04
# 110533                        chief investment officer  257340.00
# 72925                                  chief of police  319275.01
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 0              0.00  400184.25      0.00  567595.43         567595.43  2011
# 1         245131.88  137811.38      0.00  538909.28         538909.28  2011
# ...

# %%
f2.drop(index=148653,inplace=True)

# %%
f2.nsmallest(n=10,columns="TotalPay")
# Out:
#                                          JobTitle  BasePay  OvertimePay  \
# 36156  stationary engineer, water treatment plant      0.0          0.0
# 36157                            transit operator      0.0          0.0
# 36158                                  manager iv      0.0          0.0
# 70877                       deputy court clerk ii      0.0          0.0
# 70927                            registered nurse      0.0          0.0
# 70928                                     painter      0.0          0.0
# 70932                   senior eligibility worker      0.0          0.0
# 70933                   transit power line worker      0.0          0.0
# 70942                  senior collections officer      0.0          0.0
# 70956                         transit car cleaner      0.0          0.0
#
#        OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# 36156       0.0      0.00       0.0              0.00  2011
# ...

# %%
f2.nsmallest(n=10,columns="TotalPayBenefits")
# Out:
#                                           JobTitle  BasePay  OvertimePay  \
# 110530                            police officer 3      0.0          0.0
# 110529                            police officer 3      0.0          0.0
# 110528                            police officer 3      0.0          0.0
# 36156   stationary engineer, water treatment plant      0.0          0.0
# 36157                             transit operator      0.0          0.0
# 36158                                   manager iv      0.0          0.0
# 148626                               account clerk      0.0          0.0
# 148627                             general laborer      0.0          0.0
# 148629                          transcriber typist      0.0          0.0
# 148630                                   carpenter      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# 110530       0.0    -33.89       0.0            -33.89  2013
# ...

# %%
f2.nlargest(n=10,columns="TotalPayBenefits")
# Out:
#                                               JobTitle    BasePay  \
# 0       general manager-metropolitan transit authority  167411.18
# 1                      captain iii (police department)  155966.02
# 110531                                  deputy chief 3  129150.01
# 110532                               asst med examiner  318835.49
# 110533                        chief investment officer  257340.00
# 72925                                  chief of police  319275.01
# 72926                           chief, fire department  313686.01
# 110534                                 chief of police  307450.04
# 110535                          chief, fire department  302068.00
# 110536                               asst med examiner  270222.04
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 0              0.00  400184.25      0.00  567595.43         567595.43  2011
# 1         245131.88  137811.38      0.00  538909.28         538909.28  2011
# ...

# %%
f2.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63141.098892
# 2012    65667.237514
# 2013    68752.483715
# 2014    66446.063650
# Name: BasePay, dtype: float64

# %%
f2['TotalPay'].median()
# Out:
# 71439.31

# %%
f2['TotalPayBenefits'].median()
# Out:
# 92661.5

# %%
sns.set(palette="rocket")
f, axes = plt.subplots(2, 4,figsize=(15,8))
sns.histplot(df['BasePay'],ax = axes[0,0],kde=True)
sns.histplot(df['OvertimePay'],ax=axes[0,1],kde=True)
sns.histplot(df['OtherPay'],ax=axes[0,2],kde=True)
sns.histplot(df['Benefits'],ax=axes[0,3],kde=True)
sns.histplot(df['TotalPay'],ax=axes[1,0],kde=True)
sns.histplot(df['TotalPayBenefits'],ax=axes[1,1],kde=True)
sns.histplot(df['Year'],ax=axes[1,2],kde=True)
plt.show()

# %%
sns.pairplot(df,palette='Pastel1')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# ...

# %%
df1=df.corr()
sns.heatmap(df1,cmap='Pastel2',annot=True,linewidth=0.9)
plt.show()
